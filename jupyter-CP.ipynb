# %% [markdown]
# Importing Librariers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data Collection

# %%
Cars_Data=pd.read_csv('car_data.csv')
Cars_Data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# Data Preparation

# %%
Cars_Data.shape
# Out:
# (301, 9)

# %%
Cars_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
Cars_Data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
Cars_Data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
Cars_Data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
Cars_Data['Owner'].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
Cars_Data.replace({'Fuel_Type':{'Diesel':0, 'Petrol':1, 'CNG':2},
                   'Seller_Type':{'Individual':0, 'Dealer':1},
                   'Transmission':{'Manual':0, 'Automatic':1},
                   },inplace=True)

# %%
Cars_Data=Cars_Data.drop('Car_Name',axis=1)
Cars_Data['age'] = 2018-Cars_Data['Year']
Cars_Data=Cars_Data.drop('Year',axis=1)
Cars_Data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           3.35           5.59       27000          1            1
# 1           4.75           9.54       43000          0            1
# 2           7.25           9.85        6900          1            1
# 3           2.85           4.15        5200          1            1
# 4           4.60           6.87       42450          0            1
#
#    Transmission  Owner  age
# 0             0      0    4
# 1             0      0    5
# 2             0      0    1
# 3             0      0    7
# 4             0      0    4

# %% [markdown]
# Train Test Split

# %%
X=Cars_Data.drop(['Selling_Price'],axis=1)
Y=Cars_Data['Selling_Price']

# %%
print(X)
print(Y)
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          1            1             0      0
# 1             9.54       43000          0            1             0      0
# 2             9.85        6900          1            1             0      0
# 3             4.15        5200          1            1             0      0
# 4             6.87       42450          0            1             0      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          0            1             0      0
# 297           5.90       60000          1            1             0      0
# 298          11.00       87934          1            1             0      0
# 299          12.50        9000          0            1             0      0
# 300           5.90        5464          1            1             0      0
#
#      age
# 0      4
# 1      5
# 2      1
# 3      7
# ...

# %%
print(X.shape)
print(Y.shape)
# Out:
# (301, 7)
# (301,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=10)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (270, 7)
# (270,)
# (31, 7)
# (31,)

# %% [markdown]
# Model Building

# %%
Model = LinearRegression()
Model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model evaluation

# %%
y_train_pred=Model.predict(x_train)
means=mean_absolute_error(y_train_pred,y_train)
r2=r2_score(y_train,y_train_pred)

print(means)
print(r2)
# Out:
# 1.119909516363166
# 0.8897281036148665

# %%
y_train_pred=Model.predict(x_test)
means=mean_absolute_error(y_test,y_train_pred)
r2=r2_score(y_test,y_train_pred)

print(means)
print(r2)
# Out:
# 1.5348376458130322
# 0.8145040439049986

# %% [markdown]
# Predective Mechanism

# %%
Y.iloc[45]
# Out:
# np.float64(7.5)

# %%
input = np.array([12.04,15000.00,1.00,1.00,1.00,0.00,4.00]).reshape(1,-1)

pred=Model.predict(input)
print(pred)
# Out:
# [8.13337707]
